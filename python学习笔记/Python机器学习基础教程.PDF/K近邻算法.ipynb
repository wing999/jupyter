# %% [markdown]
# # K近邻算法

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris_data = load_iris()

# %%
data_column = iris_data['feature_names'] # 得到特征的列明
target_column = iris_data['target_names'] # 得到标签的列明
x_train,x_test,y_train,y_test = train_test_split(iris_data['data'],iris_data['target']) # 将总体数据切分成训练集与测试集
pd.DataFrame(iris_data['data'],columns=iris_data['feature_names'])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train,y_train) # 使用训练集训练模型
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(x_test) # 使用训练模型对测试数据进行检测

# %%
knn.score(x_test,y_test) #验证正确率
# Out:
# 0.9736842105263158

# %%
np.mean(y_pred==y_test)
# Out:
# 0.9736842105263158
